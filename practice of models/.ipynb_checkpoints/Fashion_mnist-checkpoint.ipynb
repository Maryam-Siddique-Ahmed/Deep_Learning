# %%
import tensorflow

# %%
import tensorflow as tf
import numpy as np

# %%
from tensorflow.keras.datasets import fashion_mnist

# %%
(train_images,train_labels),(test_images,test_labels)=fashion_mnist.load_data()

# %%
train_images=train_images/255.0
test_images=test_images/255.0

# %%
from tensorflow.keras import models
from tensorflow.keras import layers

# %%
model=tf.keras.models.Sequential([tf.keras.layers.Flatten(),
                        tf.keras.layers.Dense(512,activation=tf.nn.relu),
                        tf.keras.layers.Dense(10,activation=tf.nn.softmax)])

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(),
             loss="sparse_categorical_crossentropy",
             metrics=["accuracy"])

# %%
model.fit(train_images,train_labels,epochs=5,batch_size=128)
# Out:
# Train on 60000 samples
# Epoch 1/5
# 60000/60000 [==============================] - 21s 357us/sample - loss: 0.5083 - accuracy: 0.8224
# Epoch 2/5
# 60000/60000 [==============================] - 16s 271us/sample - loss: 0.3732 - accuracy: 0.8660
# Epoch 3/5
# 60000/60000 [==============================] - 16s 275us/sample - loss: 0.3316 - accuracy: 0.8803
# Epoch 4/5
# 60000/60000 [==============================] - 17s 288us/sample - loss: 0.3066 - accuracy: 0.8878
# Epoch 5/5
# 60000/60000 [==============================] - 18s 302us/sample - loss: 0.2883 - accuracy: 0.8938

# %%
test_loss,test_acc=model.evaluate(test_images,test_labels)
print("test_acc =",test_acc)
# Out:
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
# test_acc = 0.8807
